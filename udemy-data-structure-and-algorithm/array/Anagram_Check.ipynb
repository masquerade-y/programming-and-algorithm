# %% [markdown]
# # Anagram Check
#
# ## Problem
#
# Given two strings, check to see if they are anagrams. An anagram is when the two strings can be written using the exact same letters (so you can just rearrange the letters to get a different phrase or word).
#
# For example:
#
#     "public relations" is an anagram of "crap built on lies."
#
#     "clint eastwood" is an anagram of "old west action"
#
# **Note: Ignore spaces and capitalization. So "d go" is an anagram of "God" and "dog" and "o d g".**
#
# ## Solution
#
# Fill out your solution below:

# %%
def anagram(s1,s2):
    
    # remove space and convert strings to lower case
    s1 = s1.replace(" ", "").lower()
    s2 = s2.replace(" ", "").lower()
    
    # edge case: return flase when length of two string not equal
    if len(s1) != len(s2):
        return False
    
    # use dictionary to build a counter of each letter from s1 
    # and from which subtract letter in s2
    counter = {}
    
    for letter in s1:
        if letter in counter:
            counter[letter] += 1
        else:
            counter[letter] = 1
    
    for letter in s2:
        if letter in counter:
            counter[letter] -= 1
        else:
            return False
        
    for k in counter:
        if counter[k] != 0:
            return False
        
    return True

# %%
anagram('dog','god')
# Out:
# True

# %%
anagram('clint eastwood','old west action')
# Out:
# True

# %%
anagram('aa','bb')
# Out:
# False

# %%
def anagram2(s1, s2):
    
    s1 = s1.replace(" ", "").lower()
    s2 = s2.replace(" ", "").lower()
    
    return sorted(s1)==sorted(s2)

# %%
anagram2('clint eastwood','old west action')
# Out:
# True

# %%
anagram2('aaa','abc')
# Out:
# False

# %% [markdown]
# # Test Your Solution
# Run the cell below to test your solution

# %%
# %pip install nose
# Out:
# Collecting nose
#   Downloading nose-1.3.7-py3-none-any.whl (154 kB)
#      |████████████████████████████████| 154 kB 4.5 MB/s eta 0:00:01
# Installing collected packages: nose
# Successfully installed nose-1.3.7
# Note: you may need to restart the kernel to use updated packages.

# %%
"""
RUN THIS CELL TO TEST YOUR SOLUTION
"""
from nose.tools import assert_equal

class AnagramTest(object):
    
    def test(self,sol):
        assert_equal(sol('go go go','gggooo'),True)
        assert_equal(sol('abc','cba'),True)
        assert_equal(sol('hi man','hi     man'),True)
        assert_equal(sol('aabbcc','aabbc'),False)
        assert_equal(sol('123','1 2'),False)
        print("ALL TEST CASES PASSED")

# Run Tests
t = AnagramTest()
t.test(anagram)
# Out:
# ALL TEST CASES PASSED

# %%
t.test(anagram2)
# Out:
# ALL TEST CASES PASSED

# %% [markdown]
# # Good Job!
